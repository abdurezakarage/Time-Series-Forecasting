# %%
import pandas as pd
import numpy as np
from datetime import datetime
import os
# Add the project root directory to Python path
import sys
sys.path.append(os.path.abspath(os.path.join(os.path.dirname('__file__'), '..')))

# %%
from src.forcasting_model import TSLAForecaster
# Out:
# c:\Users\abdur\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/attr_value.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\abdur\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/tensor.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# ...

# %%
# Initialize forecaster
data_path = '../data/cleaned/TSLA_DATA_cleaned.csv'  # Adjust path as needed

# %%
forecaster = TSLAForecaster(data_path)
# Out:
# Train: 2140, Test: 395

# %%
# Train and evaluate models
print("\n" + "="*60)
print("TRAINING FORECASTING MODELS")
print("="*60)
# Out:
# ...
# TRAINING FORECASTING MODELS
# ...

# %%
# ARIMA model
arima_metrics = forecaster.run_arima()
# Out:
# Running ARIMA...
# Fallback ARIMA order: (1, 1, 1)
# ARIMA results saved to: ../models\arima_20250808_195134
#   - Model: ../models\arima_20250808_195134\arima_model.pkl
#   - Forecast: ../models\arima_20250808_195134\arima_forecast.csv
#   - Metrics: ../models\arima_20250808_195134\arima_metrics.json
#   - Plot: ../models\arima_20250808_195134\arima_forecast_plot.png

# %%
 # SARIMA model
sarima_metrics = forecaster.run_sarima()
# Out:
# Running SARIMA...
# No strong seasonality detected, using default m=5
# Fallback SARIMA order: (1, 1, 1), seasonal_order: (1, 1, 1, 5)
# SARIMA results saved to: ../models\sarima_20250808_195159
#   - Model: ../models\sarima_20250808_195159\sarima_model.pkl
#   - Forecast: ../models\sarima_20250808_195159\sarima_forecast.csv
#   - Metrics: ../models\sarima_20250808_195159\sarima_metrics.json
#   - Plot: ../models\sarima_20250808_195159\sarima_forecast_plot.png

# %%
# LSTM model
lstm_metrics = forecaster.run_lstm(window_size=60, units=50, layers=2, epochs=50)
# Out:
# Epoch 1/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - loss: 0.0102 - val_loss: 0.0052
# Epoch 2/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 0.0023 - val_loss: 0.0025
# Epoch 3/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0018 - val_loss: 0.0024
# Epoch 4/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 5/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 6/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.0016 - val_loss: 0.0021
# Epoch 7/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 0.0015 - val_loss: 0.0023
# Epoch 8/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 9/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 10/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 11/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.0014 - val_loss: 0.0028
# Epoch 12/50
# ...

# %%
# Compare all models
comparison_results = forecaster.compare_models()
# Out:
# Running all models and comparing results...
# Running ARIMA...
# Fallback ARIMA order: (1, 1, 1)
# ARIMA results saved to: ../models\arima_20250808_195712
#   - Model: ../models\arima_20250808_195712\arima_model.pkl
#   - Forecast: ../models\arima_20250808_195712\arima_forecast.csv
#   - Metrics: ../models\arima_20250808_195712\arima_metrics.json
#   - Plot: ../models\arima_20250808_195712\arima_forecast_plot.png
# Running SARIMA...
# No strong seasonality detected, using default m=5
# Fallback SARIMA order: (1, 1, 1), seasonal_order: (1, 1, 1, 5)
# SARIMA results saved to: ../models\sarima_20250808_195717
#   - Model: ../models\sarima_20250808_195717\sarima_model.pkl
#   - Forecast: ../models\sarima_20250808_195717\sarima_forecast.csv
#   - Metrics: ../models\sarima_20250808_195717\sarima_metrics.json
#   - Plot: ../models\sarima_20250808_195717\sarima_forecast_plot.png
# Epoch 1/50
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - loss: 0.0121 - val_loss: 0.0032
# Epoch 2/50
# ...

# %%
#save result
summary_dir = forecaster.save_all_results_summary()
# Out:
# All results summary saved to: ../models\summary_20250808_200000
#   - Model comparison: ../models\summary_20250808_200000\model_comparison.csv
#   - Summary metrics: ../models\summary_20250808_200000\summary_metrics.json
#   - Combined plot: ../models\summary_20250808_200000\all_models_comparison.png

# %%
# Save results
forecaster.save_all_results_summary()
    
print("\n" + "="*60)
print("FORECASTING PIPELINE COMPLETED")
print("="*60)
# Out:
# All results summary saved to: ../models\summary_20250808_200107
#   - Model comparison: ../models\summary_20250808_200107\model_comparison.csv
#   - Summary metrics: ../models\summary_20250808_200107\summary_metrics.json
#   - Combined plot: ../models\summary_20250808_200107\all_models_comparison.png
#
# ...
# FORECASTING PIPELINE COMPLETED
# ...
