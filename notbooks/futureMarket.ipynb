# %%
import pandas as pd
import numpy as np
from datetime import datetime
import os
# Add the project root directory to Python path
import sys
sys.path.append(os.path.abspath(os.path.join(os.path.dirname('__file__'), '..')))

# %%
from src.futureMarketForcast import FutureMarketForecaster

# %%
data_path = "../data/cleaned/TSLA_DATA_cleaned.csv"  # Adjust path as needed
models_dir = "../data/models"
forecast_months = 12

# %%
forcaster= FutureMarketForecaster(data_path, models_dir, forecast_months)
# Out:
# Loading historical data...
# ✓ Loaded 2535 days of historical data
# ✓ Date range: 2015-07-01 to 2025-07-30

# %%
# Run complete analysis
results = forcaster.run_complete_analysis()
# Out:
# Starting Future Market Forecast Analysis...
# ...
# Loading trained models...
# Loading LSTM model from lstm_20250808_195431...
# ✓ LSTM model loaded successfully
# Loading LSTM model from lstm_20250808_195947...
# ✓ LSTM model loaded successfully
# Loading ARIMA model from arima_20250808_195134...
# ✓ ARIMA model loaded successfully
# Loading ARIMA model from arima_20250808_195712...
# ✓ ARIMA model loaded successfully
# Loading SARIMA model from sarima_20250808_195159...
# ✓ SARIMA model loaded successfully
# Loading SARIMA model from sarima_20250808_195717...
# ✓ SARIMA model loaded successfully
# ✓ Loaded 3 trained models: LSTM, ARIMA, SARIMA
#
# Generating 12-month forecasts...
#
# Forecasting with LSTM...
# ✓ LSTM forecast completed
#
# Forecasting with ARIMA...
# ✓ ARIMA forecast completed
#
# Forecasting with SARIMA...
# ✓ SARIMA forecast completed
#
# Analyzing forecast trends...
# ✓ LSTM trend analysis completed
# ✓ ARIMA trend analysis completed
# ...
